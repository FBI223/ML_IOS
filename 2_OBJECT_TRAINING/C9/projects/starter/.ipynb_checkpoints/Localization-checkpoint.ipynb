# %% [markdown]
# # Localization
#
# Predict a single bounding box per image. Uses the MobileNet-based classifier as the starting point.
#
# **NOTE:** The results in this notebook are similar to those shown in the book but are not 100% the same. Because neural networks are initialized with random numbers, each training session will give slightly different results.

# %% [markdown]
# ## Load the annotations

# %%
import os, sys
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import image as tf_image
from tensorflow.keras import regularizers

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data_dir = "snacks"
train_dir = os.path.join(data_dir, "train")
val_dir = os.path.join(data_dir, "val")
test_dir = os.path.join(data_dir, "test")

# %%
train_annotations = pd.read_csv(os.path.join(data_dir, "annotations-train.csv"))
train_annotations.head()
# Out:
#            image_id     x_min     x_max     y_min     y_max class_name  folder
# 0  009218ad38ab2010  0.192620  0.729831  0.127606  0.662219       cake    cake
# 1  009218ad38ab2010  0.802377  1.000000  0.102585  0.405338  ice cream    cake
# 2  009218ad38ab2010  0.814884  0.970607  0.121768  0.357798  ice cream    cake
# 3  00c7515143b32051  0.135084  0.904315  0.081735  0.909091       cake  muffin
# 4  00c7515143b32051  0.155722  0.910569  0.083403  0.893244     muffin  muffin

# %%
len(train_annotations)
# Out:
# 7040

# %%
val_annotations = pd.read_csv(os.path.join(data_dir, "annotations-val.csv"))
test_annotations = pd.read_csv(os.path.join(data_dir, "annotations-test.csv"))

# %%
len(val_annotations), len(test_annotations)
# Out:
# (1417, 1380)

# %% [markdown]
# ## Plot training image + its bounding boxes

# %%
image_width = 224
image_height = 224

# %%
from helpers import plot_image

# %%
from keras.preprocessing import image

def plot_image_from_row(row, image_dir):
    image_path = os.path.join(image_dir, row["folder"], row["image_id"] + ".jpg")
    img = tf_image.load_img(image_path, target_size=(image_width, image_height))
    bbox = (row["x_min"], row["x_max"], row["y_min"], row["y_max"], row["class_name"])
    plot_image(img, [bbox])

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
plot_image_from_row(train_annotations.iloc[0], train_dir)

# %%
plot_image_from_row(train_annotations.iloc[2], train_dir)

# %% [markdown]
# ## Custom generator

# %%
from helpers import BoundingBoxGenerator

# %%
batch_size = 32
train_generator = BoundingBoxGenerator(train_annotations, train_dir, 
                                       image_height, image_width, 
                                       batch_size, shuffle=True)

# %%
train_iter = iter(train_generator)
X, (y_class, y_bbox) = next(train_iter)

# %%
X.shape, y_class.shape, y_bbox.shape
# Out:
# ((32, 224, 224, 3), (32,), (32, 4))

# %%
y_bbox
# Out:
# array([[3.82243e-01, 7.18692e-01, 6.08505e-01, 6.71044e-01],
#        [0.00000e+00, 1.00000e+00, 0.00000e+00, 1.00000e+00],
#        [2.06413e-01, 3.58717e-01, 7.13904e-01, 8.42246e-01],
#        [5.25880e-02, 5.43406e-01, 0.00000e+00, 4.77173e-01],
#        [4.09170e-02, 9.63993e-01, 5.40100e-02, 8.73977e-01],
#        [1.69601e-01, 2.22428e-01, 3.20667e-01, 3.82762e-01],
#        [3.36579e-01, 6.95410e-01, 3.13150e-02, 4.11273e-01],
#        [1.33917e-01, 8.58573e-01, 1.20200e-01, 9.81636e-01],
#        [1.42142e-01, 8.05806e-01, 1.32350e-02, 8.79412e-01],
#        [1.09792e-01, 7.15134e-01, 1.24722e-01, 9.15367e-01],
#        [5.03945e-01, 5.50808e-01, 2.79500e-01, 3.37636e-01],
#        [1.03720e-02, 8.02939e-01, 2.63290e-01, 1.00000e+00],
#        [2.88931e-01, 4.55285e-01, 5.01408e-01, 8.08451e-01],
#        [6.06004e-01, 1.00000e+00, 5.05316e-01, 8.82427e-01],
#        [1.01662e-01, 7.56598e-01, 4.39880e-02, 6.15836e-01],
#        [2.19512e-01, 5.94747e-01, 6.58882e-01, 9.40784e-01],
#        [2.50200e-03, 6.31019e-01, 2.51877e-01, 9.98332e-01],
#        [1.30125e-01, 7.27273e-01, 1.73149e-01, 8.08030e-01],
#        [6.31640e-02, 9.69981e-01, 1.38449e-01, 1.00000e+00],
#        [1.68860e-02, 2.65791e-01, 2.21106e-01, 6.12228e-01],
#        [4.02353e-01, 6.70588e-01, 6.79012e-01, 8.21869e-01],
#        [1.60100e-01, 5.25328e-01, 3.71831e-01, 8.52582e-01],
#        [2.21018e-01, 7.42285e-01, 1.63852e-01, 8.93684e-01],
#        [7.25773e-01, 9.99910e-01, 2.47000e-04, 3.66412e-01],
#        [7.81740e-02, 2.95810e-01, 2.34742e-01, 8.56338e-01],
#        [2.12285e-01, 5.86898e-01, 2.90960e-01, 3.65687e-01],
#        [4.09006e-01, 4.48405e-01, 4.62886e-01, 5.01251e-01],
#        [1.24875e-01, 5.76373e-01, 5.34536e-01, 9.37178e-01],
#        [0.00000e+00, 9.99172e-01, 1.23827e-01, 9.92495e-01],
#        [4.94650e-01, 8.80926e-01, 2.39610e-02, 4.37701e-01],
#        [1.54481e-01, 1.00000e+00, 3.73818e-01, 1.00000e+00],
#        [3.81490e-02, 4.16510e-01, 2.52485e-01, 5.88469e-01]])

# %%
y_class
# Out:
# array([14,  3,  6,  2, 18,  7, 19,  3, 12, 13, 17, 10, 17, 11,  3,  6, 15,
#         2,  8,  5,  6,  0, 13,  2,  7,  4,  7, 10,  7,  6, 10, 17])

# %%
from helpers import labels
list(map(lambda x: labels[x], y_class))
# Out:
# ['popcorn',
#  'candy',
#  'doughnut',
#  'cake',
#  'waffle',
#  'grape',
#  'watermelon',
#  'candy',
#  'orange',
#  'pineapple',
#  'strawberry',
#  'juice',
#  'strawberry',
#  'muffin',
#  'candy',
#  'doughnut',
#  'pretzel',
#  'cake',
#  'hot dog',
#  'cookie',
#  'doughnut',
#  'apple',
#  'pineapple',
#  'cake',
#  'grape',
#  'carrot',
#  'grape',
#  'juice',
#  'grape',
#  'doughnut',
#  'juice',
#  'strawberry']

# %%
len(train_generator)
# Out:
# 220

# %%
def plot_image_from_batch(X, y_class, y_bbox, img_idx):
    class_name = labels[y_class[img_idx]]
    bbox = y_bbox[img_idx]
    plot_image(X[img_idx], [[*bbox, class_name]])

# %%
plot_image_from_batch(X, y_class, y_bbox, 7)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].

# %%
X, (y_class, y_bbox) = next(train_iter)

# %% [markdown]
# ## Load the best model from last time

# %%
import keras
from keras.models import Sequential
from keras.layers import *
from keras.models import Model, load_model
from keras import optimizers, callbacks
import keras.backend as K

classifier_model = load_model("checkpoints/multisnacks-0.7162-0.8419.hdf5")

# %%
classifier_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  global_average_pooling2d_3   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 20)                20500
#
#  activation_3 (Activation)   (None, 20)                0
#
# =================================================================
# Total params: 3,249,364
# Trainable params: 3,227,476
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# ## Add the bounding box predictor to the model

# %%
from tensorflow.keras import regularizers
num_classes = 20

# The MobileNet feature extractor is the first "layer".
base_model = classifier_model.layers[0]

# Add a global average pooling layer after MobileNet.
pool = GlobalAveragePooling2D()(base_model.outputs[0])

# Reconstruct the classifier layers.
clf = Dropout(0.7)(pool)
clf = Dense(num_classes, kernel_regularizer=regularizers.l2(0.01), name="dense_class")(clf)
clf = Activation("softmax", name="class_prediction")(clf)

# Add new layers for the bounding box predictor.
bbox = Conv2D(512, 3, padding="same")(base_model.outputs[0])
bbox = BatchNormalization()(bbox)
bbox = Activation("relu")(bbox)
bbox = GlobalAveragePooling2D()(bbox)
bbox = Dense(4, name="bbox_prediction")(bbox)

# Create the new model.
model = Model(inputs=base_model.inputs, outputs=[clf, bbox])

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 225, 225, 3)  0           ['input_3[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 32  864         ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 32  128         ['conv1[0][0]']
#                                 )
#
#  conv1_relu (ReLU)              (None, 112, 112, 32  0           ['conv1_bn[0][0]']
#                                 )
#
#  conv_dw_1 (DepthwiseConv2D)    (None, 112, 112, 32  288         ['conv1_relu[0][0]']
#                                 )
#
#  conv_dw_1_bn (BatchNormalizati  (None, 112, 112, 32  128        ['conv_dw_1[0][0]']
#  on)                            )
#
#  conv_dw_1_relu (ReLU)          (None, 112, 112, 32  0           ['conv_dw_1_bn[0][0]']
#                                 )
#
#  conv_pw_1 (Conv2D)             (None, 112, 112, 64  2048        ['conv_dw_1_relu[0][0]']
#                                 )
#
#  conv_pw_1_bn (BatchNormalizati  (None, 112, 112, 64  256        ['conv_pw_1[0][0]']
#  on)                            )
#
#  conv_pw_1_relu (ReLU)          (None, 112, 112, 64  0           ['conv_pw_1_bn[0][0]']
#                                 )
#
#  conv_pad_2 (ZeroPadding2D)     (None, 113, 113, 64  0           ['conv_pw_1_relu[0][0]']
#                                 )
#
#  conv_dw_2 (DepthwiseConv2D)    (None, 56, 56, 64)   576         ['conv_pad_2[0][0]']
#
#  conv_dw_2_bn (BatchNormalizati  (None, 56, 56, 64)  256         ['conv_dw_2[0][0]']
#  on)
#
#  conv_dw_2_relu (ReLU)          (None, 56, 56, 64)   0           ['conv_dw_2_bn[0][0]']
#
#  conv_pw_2 (Conv2D)             (None, 56, 56, 128)  8192        ['conv_dw_2_relu[0][0]']
#
#  conv_pw_2_bn (BatchNormalizati  (None, 56, 56, 128)  512        ['conv_pw_2[0][0]']
#  on)
#
#  conv_pw_2_relu (ReLU)          (None, 56, 56, 128)  0           ['conv_pw_2_bn[0][0]']
#
#  conv_dw_3 (DepthwiseConv2D)    (None, 56, 56, 128)  1152        ['conv_pw_2_relu[0][0]']
#
#  conv_dw_3_bn (BatchNormalizati  (None, 56, 56, 128)  512        ['conv_dw_3[0][0]']
#  on)
#
#  conv_dw_3_relu (ReLU)          (None, 56, 56, 128)  0           ['conv_dw_3_bn[0][0]']
#
#  conv_pw_3 (Conv2D)             (None, 56, 56, 128)  16384       ['conv_dw_3_relu[0][0]']
#
#  conv_pw_3_bn (BatchNormalizati  (None, 56, 56, 128)  512        ['conv_pw_3[0][0]']
#  on)
#
#  conv_pw_3_relu (ReLU)          (None, 56, 56, 128)  0           ['conv_pw_3_bn[0][0]']
#
#  conv_pad_4 (ZeroPadding2D)     (None, 57, 57, 128)  0           ['conv_pw_3_relu[0][0]']
#
#  conv_dw_4 (DepthwiseConv2D)    (None, 28, 28, 128)  1152        ['conv_pad_4[0][0]']
#
#  conv_dw_4_bn (BatchNormalizati  (None, 28, 28, 128)  512        ['conv_dw_4[0][0]']
#  on)
#
#  conv_dw_4_relu (ReLU)          (None, 28, 28, 128)  0           ['conv_dw_4_bn[0][0]']
#
#  conv_pw_4 (Conv2D)             (None, 28, 28, 256)  32768       ['conv_dw_4_relu[0][0]']
#
#  conv_pw_4_bn (BatchNormalizati  (None, 28, 28, 256)  1024       ['conv_pw_4[0][0]']
#  on)
#
#  conv_pw_4_relu (ReLU)          (None, 28, 28, 256)  0           ['conv_pw_4_bn[0][0]']
#
#  conv_dw_5 (DepthwiseConv2D)    (None, 28, 28, 256)  2304        ['conv_pw_4_relu[0][0]']
#
#  conv_dw_5_bn (BatchNormalizati  (None, 28, 28, 256)  1024       ['conv_dw_5[0][0]']
#  on)
#
#  conv_dw_5_relu (ReLU)          (None, 28, 28, 256)  0           ['conv_dw_5_bn[0][0]']
#
#  conv_pw_5 (Conv2D)             (None, 28, 28, 256)  65536       ['conv_dw_5_relu[0][0]']
#
#  conv_pw_5_bn (BatchNormalizati  (None, 28, 28, 256)  1024       ['conv_pw_5[0][0]']
#  on)
#
#  conv_pw_5_relu (ReLU)          (None, 28, 28, 256)  0           ['conv_pw_5_bn[0][0]']
#
#  conv_pad_6 (ZeroPadding2D)     (None, 29, 29, 256)  0           ['conv_pw_5_relu[0][0]']
#
#  conv_dw_6 (DepthwiseConv2D)    (None, 14, 14, 256)  2304        ['conv_pad_6[0][0]']
#
#  conv_dw_6_bn (BatchNormalizati  (None, 14, 14, 256)  1024       ['conv_dw_6[0][0]']
#  on)
#
#  conv_dw_6_relu (ReLU)          (None, 14, 14, 256)  0           ['conv_dw_6_bn[0][0]']
#
#  conv_pw_6 (Conv2D)             (None, 14, 14, 512)  131072      ['conv_dw_6_relu[0][0]']
#
#  conv_pw_6_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_6[0][0]']
#  on)
#
#  conv_pw_6_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_6_bn[0][0]']
#
#  conv_dw_7 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_6_relu[0][0]']
#
#  conv_dw_7_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_7[0][0]']
#  on)
#
#  conv_dw_7_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_7_bn[0][0]']
#
#  conv_pw_7 (Conv2D)             (None, 14, 14, 512)  262144      ['conv_dw_7_relu[0][0]']
#
#  conv_pw_7_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_7[0][0]']
#  on)
#
#  conv_pw_7_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_7_bn[0][0]']
#
#  conv_dw_8 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_7_relu[0][0]']
#
#  conv_dw_8_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_8[0][0]']
#  on)
#
#  conv_dw_8_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_8_bn[0][0]']
#
#  conv_pw_8 (Conv2D)             (None, 14, 14, 512)  262144      ['conv_dw_8_relu[0][0]']
#
#  conv_pw_8_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_8[0][0]']
#  on)
#
#  conv_pw_8_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_8_bn[0][0]']
#
#  conv_dw_9 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_8_relu[0][0]']
#
#  conv_dw_9_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_9[0][0]']
#  on)
#
#  conv_dw_9_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_9_bn[0][0]']
#
#  conv_pw_9 (Conv2D)             (None, 14, 14, 512)  262144      ['conv_dw_9_relu[0][0]']
#
#  conv_pw_9_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_pw_9[0][0]']
#  on)
#
#  conv_pw_9_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_pw_9_bn[0][0]']
#
#  conv_dw_10 (DepthwiseConv2D)   (None, 14, 14, 512)  4608        ['conv_pw_9_relu[0][0]']
#
#  conv_dw_10_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_dw_10[0][0]']
#  ion)
#
#  conv_dw_10_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_dw_10_bn[0][0]']
#
#  conv_pw_10 (Conv2D)            (None, 14, 14, 512)  262144      ['conv_dw_10_relu[0][0]']
#
#  conv_pw_10_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_pw_10[0][0]']
#  ion)
#  conv_pw_10_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_pw_10_bn[0][0]']
#
#  conv_dw_11 (DepthwiseConv2D)   (None, 14, 14, 512)  4608        ['conv_pw_10_relu[0][0]']
#
#  conv_dw_11_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_dw_11[0][0]']
#  ion)
#
#  conv_dw_11_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_dw_11_bn[0][0]']
#
#  conv_pw_11 (Conv2D)            (None, 14, 14, 512)  262144      ['conv_dw_11_relu[0][0]']
#
#  conv_pw_11_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_pw_11[0][0]']
#  ion)
#
#  conv_pw_11_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_pw_11_bn[0][0]']
#
#  conv_pad_12 (ZeroPadding2D)    (None, 15, 15, 512)  0           ['conv_pw_11_relu[0][0]']
#
#  conv_dw_12 (DepthwiseConv2D)   (None, 7, 7, 512)    4608        ['conv_pad_12[0][0]']
#
#  conv_dw_12_bn (BatchNormalizat  (None, 7, 7, 512)   2048        ['conv_dw_12[0][0]']
#  ion)
#
#  conv_dw_12_relu (ReLU)         (None, 7, 7, 512)    0           ['conv_dw_12_bn[0][0]']
#
#  conv_pw_12 (Conv2D)            (None, 7, 7, 1024)   524288      ['conv_dw_12_relu[0][0]']
#
#  conv_pw_12_bn (BatchNormalizat  (None, 7, 7, 1024)  4096        ['conv_pw_12[0][0]']
#  ion)
#
#  conv_pw_12_relu (ReLU)         (None, 7, 7, 1024)   0           ['conv_pw_12_bn[0][0]']
#
#  conv_dw_13 (DepthwiseConv2D)   (None, 7, 7, 1024)   9216        ['conv_pw_12_relu[0][0]']
#
#  conv_dw_13_bn (BatchNormalizat  (None, 7, 7, 1024)  4096        ['conv_dw_13[0][0]']
#  ion)
#
#  conv_dw_13_relu (ReLU)         (None, 7, 7, 1024)   0           ['conv_dw_13_bn[0][0]']
#
#  conv_pw_13 (Conv2D)            (None, 7, 7, 1024)   1048576     ['conv_dw_13_relu[0][0]']
#
#  conv_pw_13_bn (BatchNormalizat  (None, 7, 7, 1024)  4096        ['conv_pw_13[0][0]']
#  ion)
#
#  conv_pw_13_relu (ReLU)         (None, 7, 7, 1024)   0           ['conv_pw_13_bn[0][0]']
#
#  conv2d (Conv2D)                (None, 7, 7, 512)    4719104     ['conv_pw_13_relu[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['conv_pw_13_relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization (BatchNorm  (None, 7, 7, 512)   2048        ['conv2d[0][0]']
#  alization)
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  activation (Activation)        (None, 7, 7, 512)    0           ['batch_normalization[0][0]']
#
#  dense_class (Dense)            (None, 20)           20500       ['dropout_1[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 512)         0           ['activation[0][0]']
#  obalAveragePooling2D)
#
#  class_prediction (Activation)  (None, 20)           0           ['dense_class[0][0]']
#
#  bbox_prediction (Dense)        (None, 4)            2052        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 7,972,568
# Trainable params: 4,742,680
# Non-trainable params: 3,229,888
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file="bbox_model.png")

# %% [markdown]
# Put the old weights back, or the classifier won't work anymore:

# %%
layer_dict = {layer.name:i for i, layer in enumerate(model.layers)}

# Get the weights from the checkpoint model.
weights, biases = classifier_model.layers[-2].get_weights()

# Put them into the new model.
model.layers[layer_dict["dense_class"]].set_weights([weights, biases])

# %%
model.compile(loss=["sparse_categorical_crossentropy", "mse"],
              loss_weights=[1.0, 10.0],
              optimizer=optimizers.Adam(learning_rate=1e-3),
              metrics={ "class_prediction": "accuracy" })

# %% [markdown]
# ## Try the model on an image

# %%
#from keras.applications.mobilenet import preprocess_input
#from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

img = load_img(train_dir + "/salad/2ad03070c5900aac.jpg", target_size=(image_width, image_height))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x346722BE0>

# %%
x = img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
preds
# Out:
# 2025-05-11 20:04:23.078486: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 0s 258ms/step
# [array([[5.5658977e-05, 7.1897801e-07, 7.4316747e-05, 4.5374900e-06,
#          2.9821679e-04, 2.9114558e-06, 5.2616433e-06, 4.8986229e-04,
#          6.5828278e-04, 6.8758114e-04, 3.6887897e-05, 6.2949430e-06,
#          1.6075559e-05, 2.1348763e-04, 1.9503798e-06, 8.5053313e-07,
#          9.7398043e-01, 2.2265129e-03, 1.5831968e-03, 1.9656973e-02]],
#        dtype=float32),
#  array([[-0.5683281, -0.6756018, -1.5233047,  3.9724128]], dtype=float32)]

# %%
len(preds)
# Out:
# 2

# %%
plt.figure(figsize=(10, 5))
plt.bar(range(num_classes), preds[0].squeeze())
plt.xticks(range(num_classes), labels, rotation=90, fontsize=20)
plt.show()

# %%
preds = classifier_model.predict(x)
preds
# Out:
# 1/1 [==============================] - 0s 166ms/step
# array([[5.5658977e-05, 7.1897801e-07, 7.4316747e-05, 4.5374900e-06,
#         2.9821679e-04, 2.9114558e-06, 5.2616433e-06, 4.8986229e-04,
#         6.5828278e-04, 6.8758114e-04, 3.6887897e-05, 6.2949430e-06,
#         1.6075559e-05, 2.1348763e-04, 1.9503798e-06, 8.5053313e-07,
#         9.7398043e-01, 2.2265129e-03, 1.5831968e-03, 1.9656973e-02]],
#       dtype=float32)

# %%
preds = model.predict(train_generator)
# Out:
# 220/220 [==============================] - 35s 161ms/step

# %%
preds[1].shape
# Out:
# (7040, 4)

# %% [markdown]
# ## Train the model

# %%
val_generator = BoundingBoxGenerator(val_annotations, val_dir, 
                                     image_height, image_width, 
                                     batch_size, shuffle=False)

# %%
from helpers import combine_histories, plot_loss, plot_bbox_loss

# %%
histories = []

# %%
histories.append(model.fit(train_generator, 
                                     steps_per_epoch=len(train_generator),
                                     epochs=5,
                                     validation_data=val_generator,
                                     validation_steps=len(val_generator),
                                     workers=8))
# Out:
# Epoch 1/5
# /var/folders/zc/2gdqs8nn3vq7ws_jb8h13rwc0000gn/T/ipykernel_37518/2467376597.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   histories.append(model.fit_generator(train_generator,
# 220/220 [==============================] - 53s 238ms/step - loss: 2.2259 - class_prediction_loss: 0.3923 - bbox_prediction_loss: 0.1697 - class_prediction_accuracy: 0.8977 - val_loss: 1.2105 - val_class_prediction_loss: 0.5971 - val_bbox_prediction_loss: 0.0479 - val_class_prediction_accuracy: 0.8210
# Epoch 2/5
# 220/220 [==============================] - 53s 241ms/step - loss: 0.8707 - class_prediction_loss: 0.3653 - bbox_prediction_loss: 0.0370 - class_prediction_accuracy: 0.9006 - val_loss: 1.1627 - val_class_prediction_loss: 0.5879 - val_bbox_prediction_loss: 0.0438 - val_class_prediction_accuracy: 0.8182
# Epoch 3/5
# 220/220 [==============================] - 53s 242ms/step - loss: 0.8240 - class_prediction_loss: 0.3530 - bbox_prediction_loss: 0.0332 - class_prediction_accuracy: 0.8994 - val_loss: 1.1959 - val_class_prediction_loss: 0.5931 - val_bbox_prediction_loss: 0.0461 - val_class_prediction_accuracy: 0.8196
# Epoch 4/5
# 220/220 [==============================] - 54s 247ms/step - loss: 0.8012 - class_prediction_loss: 0.3544 - bbox_prediction_loss: 0.0305 - class_prediction_accuracy: 0.9003 - val_loss: 1.2132 - val_class_prediction_loss: 0.6179 - val_bbox_prediction_loss: 0.0453 - val_class_prediction_accuracy: 0.8139
# Epoch 5/5
# 220/220 [==============================] - 54s 247ms/step - loss: 0.7913 - class_prediction_loss: 0.3510 - bbox_prediction_loss: 0.0296 - class_prediction_accuracy: 0.8952 - val_loss: 1.1866 - val_class_prediction_loss: 0.6069 - val_bbox_prediction_loss: 0.0435 - val_class_prediction_accuracy: 0.8239

# %%
history = combine_histories(histories)
plot_loss(history)

# %%
plot_bbox_loss(history)

# %% [markdown]
# ## Adding the IOU metric

# %%
from helpers import iou, MeanIOU, plot_iou

bbox1 = [0.2, 0.7, 0.3, 0.6, "bbox1"]
bbox2 = [0.4, 0.6, 0.2, 0.5, "bbox2"]
iou(bbox1, bbox2)
# Out:
# 0.23529411764705882

# %%
plot_image(img, [bbox1, bbox2])

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Metric

class MeanIoUMetric(Metric):
    def __init__(self, name="mean_iou", **kwargs):
        super(MeanIoUMetric, self).__init__(name=name, **kwargs)
        self.total_iou = self.add_weight(name="total_iou", initializer="zeros")
        self.count = self.add_weight(name="count", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Coordinates: [x_min, x_max, y_min, y_max]
        xA = tf.maximum(y_true[:, 0], y_pred[:, 0])
        yA = tf.maximum(y_true[:, 2], y_pred[:, 2])
        xB = tf.minimum(y_true[:, 1], y_pred[:, 1])
        yB = tf.minimum(y_true[:, 3], y_pred[:, 3])

        inter_area = tf.maximum(0.0, xB - xA) * tf.maximum(0.0, yB - yA)

        box_true_area = (y_true[:, 1] - y_true[:, 0]) * (y_true[:, 3] - y_true[:, 2])
        box_pred_area = (y_pred[:, 1] - y_pred[:, 0]) * (y_pred[:, 3] - y_pred[:, 2])
        union_area = box_true_area + box_pred_area - inter_area

        iou = tf.math.divide_no_nan(inter_area, union_area)

        self.total_iou.assign_add(tf.reduce_sum(iou))
        self.count.assign_add(tf.cast(tf.size(iou), tf.float32))

    def result(self):
        return tf.math.divide_no_nan(self.total_iou, self.count)

    def reset_state(self):
        self.total_iou.assign(0.0)
        self.count.assign(0.0)

# %% [markdown]
# **NOTE:** At this point I went back to the beginning of the notebook and created the model again. That way you can see clearer how the mean IOU increases over time. Just run all the cells from the section **Add the bounding box predictor to the model** again, then come back here.

# %%
model.compile(loss=["sparse_categorical_crossentropy", "mse"],
              loss_weights=[1.0, 10.0],
              optimizer=optimizers.Adam(learning_rate=1e-3),
              metrics={ "class_prediction": "accuracy", 
                        "bbox_prediction": MeanIoUMetric() })

# %%
histories = []

# %%
histories.append(model.fit(train_generator, 
                                     steps_per_epoch=len(train_generator),
                                     epochs=5,
                                     validation_data=val_generator,
                                     validation_steps=len(val_generator),
                                     workers=8))
# Out:
# Epoch 1/5
# 220/220 [==============================] - 55s 247ms/step - loss: 0.8216 - class_prediction_loss: 0.3598 - bbox_prediction_loss: 0.0315 - class_prediction_accuracy: 0.8999 - bbox_prediction_mean_iou: 0.3511 - val_loss: 1.1774 - val_class_prediction_loss: 0.6105 - val_bbox_prediction_loss: 0.0417 - val_class_prediction_accuracy: 0.8281 - val_bbox_prediction_mean_iou: 0.3158
# Epoch 2/5
# 220/220 [==============================] - 54s 245ms/step - loss: 0.7844 - class_prediction_loss: 0.3511 - bbox_prediction_loss: 0.0284 - class_prediction_accuracy: 0.9017 - bbox_prediction_mean_iou: 0.3699 - val_loss: 1.1737 - val_class_prediction_loss: 0.5815 - val_bbox_prediction_loss: 0.0444 - val_class_prediction_accuracy: 0.8303 - val_bbox_prediction_mean_iou: 0.3411
# Epoch 3/5
# 220/220 [==============================] - 54s 246ms/step - loss: 0.7811 - class_prediction_loss: 0.3585 - bbox_prediction_loss: 0.0273 - class_prediction_accuracy: 0.8912 - bbox_prediction_mean_iou: 0.3775 - val_loss: 1.1819 - val_class_prediction_loss: 0.5721 - val_bbox_prediction_loss: 0.0460 - val_class_prediction_accuracy: 0.8317 - val_bbox_prediction_mean_iou: 0.3039
# Epoch 4/5
# 220/220 [==============================] - 54s 247ms/step - loss: 0.7497 - class_prediction_loss: 0.3501 - bbox_prediction_loss: 0.0251 - class_prediction_accuracy: 0.8990 - bbox_prediction_mean_iou: 0.3945 - val_loss: 1.1255 - val_class_prediction_loss: 0.5688 - val_bbox_prediction_loss: 0.0409 - val_class_prediction_accuracy: 0.8359 - val_bbox_prediction_mean_iou: 0.2864
# Epoch 5/5
# 220/220 [==============================] - 55s 250ms/step - loss: 0.7461 - class_prediction_loss: 0.3541 - bbox_prediction_loss: 0.0245 - class_prediction_accuracy: 0.8976 - bbox_prediction_mean_iou: 0.3979 - val_loss: 1.1360 - val_class_prediction_loss: 0.5782 - val_bbox_prediction_loss: 0.0411 - val_class_prediction_accuracy: 0.8281 - val_bbox_prediction_mean_iou: 0.2799

# %%
K.set_value(model.optimizer.lr, K.get_value(model.optimizer.lr) / 10)

# %%
histories.append(model.fit(train_generator, 
                                     steps_per_epoch=len(train_generator),
                                     epochs=5,
                                     validation_data=val_generator,
                                     validation_steps=len(val_generator),
                                     workers=8))
# Out:
# Epoch 1/5
# 220/220 [==============================] - 55s 250ms/step - loss: 0.6464 - class_prediction_loss: 0.3093 - bbox_prediction_loss: 0.0192 - class_prediction_accuracy: 0.9124 - bbox_prediction_mean_iou: 0.4467 - val_loss: 1.0802 - val_class_prediction_loss: 0.5560 - val_bbox_prediction_loss: 0.0381 - val_class_prediction_accuracy: 0.8352 - val_bbox_prediction_mean_iou: 0.3426
# Epoch 2/5
# 220/220 [==============================] - 57s 259ms/step - loss: 0.6296 - class_prediction_loss: 0.3043 - bbox_prediction_loss: 0.0183 - class_prediction_accuracy: 0.9119 - bbox_prediction_mean_iou: 0.4565 - val_loss: 1.0817 - val_class_prediction_loss: 0.5561 - val_bbox_prediction_loss: 0.0385 - val_class_prediction_accuracy: 0.8303 - val_bbox_prediction_mean_iou: 0.3467
# Epoch 3/5
# 220/220 [==============================] - 58s 262ms/step - loss: 0.6194 - class_prediction_loss: 0.3004 - bbox_prediction_loss: 0.0180 - class_prediction_accuracy: 0.9097 - bbox_prediction_mean_iou: 0.4600 - val_loss: 1.0832 - val_class_prediction_loss: 0.5637 - val_bbox_prediction_loss: 0.0382 - val_class_prediction_accuracy: 0.8317 - val_bbox_prediction_mean_iou: 0.3363
# Epoch 4/5
# 220/220 [==============================] - 55s 248ms/step - loss: 0.6029 - class_prediction_loss: 0.2876 - bbox_prediction_loss: 0.0180 - class_prediction_accuracy: 0.9172 - bbox_prediction_mean_iou: 0.4609 - val_loss: 1.0925 - val_class_prediction_loss: 0.5648 - val_bbox_prediction_loss: 0.0394 - val_class_prediction_accuracy: 0.8303 - val_bbox_prediction_mean_iou: 0.3552
# Epoch 5/5
# 220/220 [==============================] - 56s 252ms/step - loss: 0.6049 - class_prediction_loss: 0.2949 - bbox_prediction_loss: 0.0178 - class_prediction_accuracy: 0.9141 - bbox_prediction_mean_iou: 0.4642 - val_loss: 1.0818 - val_class_prediction_loss: 0.5567 - val_bbox_prediction_loss: 0.0394 - val_class_prediction_accuracy: 0.8267 - val_bbox_prediction_mean_iou: 0.3142

# %%
K.set_value(model.optimizer.lr, K.get_value(model.optimizer.lr) / 10)

# %%
histories.append(model.fit(train_generator, 
                                     steps_per_epoch=len(train_generator),
                                     epochs=5,
                                     validation_data=val_generator,
                                     validation_steps=len(val_generator),
                                     workers=8))
# Out:
# Epoch 1/5
# /var/folders/zc/2gdqs8nn3vq7ws_jb8h13rwc0000gn/T/ipykernel_37518/2467376597.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   histories.append(model.fit_generator(train_generator,
# 220/220 [==============================] - 56s 253ms/step - loss: 0.5893 - class_prediction_loss: 0.2881 - bbox_prediction_loss: 0.0170 - class_prediction_accuracy: 0.9196 - bbox_prediction_mean_iou: 0.4705 - val_loss: 1.0735 - val_class_prediction_loss: 0.5567 - val_bbox_prediction_loss: 0.0386 - val_class_prediction_accuracy: 0.8267 - val_bbox_prediction_mean_iou: 0.3411
# Epoch 2/5
# 220/220 [==============================] - 55s 250ms/step - loss: 0.5946 - class_prediction_loss: 0.2957 - bbox_prediction_loss: 0.0168 - class_prediction_accuracy: 0.9118 - bbox_prediction_mean_iou: 0.4767 - val_loss: 1.0733 - val_class_prediction_loss: 0.5565 - val_bbox_prediction_loss: 0.0386 - val_class_prediction_accuracy: 0.8288 - val_bbox_prediction_mean_iou: 0.3398
# Epoch 3/5
# 220/220 [==============================] - 55s 249ms/step - loss: 0.5920 - class_prediction_loss: 0.2933 - bbox_prediction_loss: 0.0168 - class_prediction_accuracy: 0.9111 - bbox_prediction_mean_iou: 0.4753 - val_loss: 1.0717 - val_class_prediction_loss: 0.5561 - val_bbox_prediction_loss: 0.0386 - val_class_prediction_accuracy: 0.8295 - val_bbox_prediction_mean_iou: 0.3407
# Epoch 4/5
# 220/220 [==============================] - 55s 252ms/step - loss: 0.5889 - class_prediction_loss: 0.2913 - bbox_prediction_loss: 0.0168 - class_prediction_accuracy: 0.9190 - bbox_prediction_mean_iou: 0.4764 - val_loss: 1.0721 - val_class_prediction_loss: 0.5560 - val_bbox_prediction_loss: 0.0386 - val_class_prediction_accuracy: 0.8303 - val_bbox_prediction_mean_iou: 0.3396
# Epoch 5/5
# 220/220 [==============================] - 56s 253ms/step - loss: 0.5857 - class_prediction_loss: 0.2882 - bbox_prediction_loss: 0.0168 - class_prediction_accuracy: 0.9161 - bbox_prediction_mean_iou: 0.4773 - val_loss: 1.0724 - val_class_prediction_loss: 0.5557 - val_bbox_prediction_loss: 0.0387 - val_class_prediction_accuracy: 0.8310 - val_bbox_prediction_mean_iou: 0.3424

# %%
history = combine_histories(histories)
plot_loss(history)

# %%
plot_bbox_loss(history)

# %%
plot_iou(history)

# %% [markdown]
# ## Try the model on the test set

# %%
def plot_prediction(row, image_dir):
    image_path = os.path.join(image_dir, row["folder"], row["image_id"] + ".jpg")
    img = load_img(image_path, target_size=(image_width, image_height))
    bbox_true = [row["x_min"], row["x_max"], row["y_min"], row["y_max"], row["class_name"].upper()]
    
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    pred = model.predict(x)
    bbox_pred = [*pred[1][0], labels[np.argmax(pred[0])]]
    
    plot_image(img, [bbox_true, bbox_pred])
   
    print("IOU:", iou(bbox_true, bbox_pred))

# %%
row_index = np.random.randint(len(test_annotations))
row = test_annotations.iloc[row_index]
plot_prediction(row, test_dir)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# IOU: 0.62866474630092
